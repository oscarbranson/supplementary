# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from glob import glob

# %%
fs = glob('*_compiled.csv')
subs = []
for f in fs:
    subs.append(pd.read_csv(f, header=[0,1]))
    
dat = pd.concat(subs)

# %%
dat.to_csv('coretops_compiled.csv')

# %%
for s in dat.metadata.species.unique():
    ind = dat.metadata.species == s
    plt.scatter(dat.calculated.BO4[ind] / dat.calculated.CO3[ind]**0.5, dat.measured['B/Ca'][ind], label=s, lw=1, edgecolor='w')
    
plt.legend(bbox_to_anchor=(1, 0., 0, 1))
